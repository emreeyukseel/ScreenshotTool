# %%
import os
import cv2
import numpy as np
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator
from IPython.display import clear_output
# Out:
# Using TensorFlow backend.

# %%
class ExtractImage(object):
    def __init__(self,image_name):
        self.image_name = image_name
        self.original_image = cv2.imread(self.image_name)

        self.original_image = cv2.resize(self.original_image, (600,600))
        self.clone = self.original_image.copy()

        cv2.namedWindow('image')
        cv2.setMouseCallback('image', self.extract_coordinates)
        self.image_coordinates = []

    def extract_coordinates(self, event, x, y, flags, parameters):
        if event == cv2.EVENT_LBUTTONDOWN:
            self.image_coordinates = [(x,y)]

        elif event == cv2.EVENT_LBUTTONUP:
            self.image_coordinates.append((x,y))
            self.crop_ROI()

            # Draw rectangle around region of interst(ROI)
            cv2.rectangle(self.clone, self.image_coordinates[0], self.image_coordinates[1], (255,0,0), 2)
            cv2.imshow("image", self.clone) 

        # Clear all drawn boxes on right mouse button click
        elif event == cv2.EVENT_RBUTTONDOWN:
            self.clone = self.original_image.copy()

    def crop_ROI(self):
        self.cropped_image = self.clone.copy()
        self.cropped_image = self.cropped_image[self.image_coordinates[0][1]:self.image_coordinates[1][1],
                                                self.image_coordinates[0][0]:self.image_coordinates[1][0]]

        print('Cropped image: {} {}'.format(self.image_coordinates[0], self.image_coordinates[1]))
    
    def save_with_augmentation(self, count):
        # Generating 6 photos rotated 90 degrees
        # If you want you can use another augmentation techniques
        samples = expand_dims(self.cropped_image, 0)
        datagen = ImageDataGenerator(rotation_range=90)
        it = datagen.flow(samples, batch_size=1)
        
        for i in range(6):
            batch = it.next()
            image = batch[0].astype('uint8')
            cv2.imwrite(f'Output/Augmented/{count}_{str(i)}.jpg', image)
            
    def show_image(self):
        return self.clone
    
    def show_cropped_ROI(self):
        cv2.imshow('cropped image', self.cropped_image)
        
    def save_cropped_ROI(self, count):
        cv2.imwrite(f'Output/Cropped/{count}.jpg', self.cropped_image)
        
if __name__ == '__main__':
    folder = "Data/Smoking"
    for file in os.listdir(folder):
        count = file.split('.')[0]
        path = folder+'/'+file
        print(path)
        extract_image = ExtractImage(path)
        try:
            while True:
                cv2.imshow('image', extract_image.show_image())
                key = cv2.waitKey(1)
                if key == ord('q'): # Skips current image
                    cv2.destroyAllWindows()
                    cv2.waitKey(0)
                    break

                if key == ord('c'): # Crop image with keyboard 'c'
                    extract_image.show_cropped_ROI()

                if key == ord('s'): # Save cropped image with keyboard 's'
                    extract_image.save_cropped_ROI()
                    print('Cropped image saved !')

                if key == ord('a'): # Save cropped image with augmentation
                    extract_image.save_with_augmentation(count)
                    extract_image.save_cropped_ROI(count)
                    print('Augmented cropped images saved !')
                    cv2.destroyAllWindows()
                    cv2.waitKey(0)
                    break

                if key == 27: # Stops program upon hittin Esc key
                    cv2.destroyAllWindows()
                    cv2.waitKey(0)
                    raise Exception
        except Exception:
            break
# Out:
# Data/Smoking/0.jpg
# Data/Smoking/1.jpg
# Data/Smoking/10.jpg
# Data/Smoking/100.jpg
# Data/Smoking/101.jpg
# Data/Smoking/102.jpg
# Data/Smoking/103.jpg
# Data/Smoking/104.jpg
# Data/Smoking/105.jpg
# Data/Smoking/106.jpg
# Data/Smoking/107.jpg
# Data/Smoking/108.jpg
# Cropped image: (6, 70) (402, 592)
# Augmented cropped images saved !
# Data/Smoking/109.jpg
# Cropped image: (129, 169) (546, 597)
# Augmented cropped images saved !
# Data/Smoking/11.jpg
# Cropped image: (61, 129) (289, 597)
# Augmented cropped images saved !
# Data/Smoking/110.jpg
# Cropped image: (138, 22) (592, 586)
# Augmented cropped images saved !
# Data/Smoking/111.jpg
# Cropped image: (4, 4) (392, 597)
# Augmented cropped images saved !
# Data/Smoking/112.jpg
# Cropped image: (109, 161) (447, 595)
# Augmented cropped images saved !
# Data/Smoking/113.jpg
# Cropped image: (209, 3) (418, 294)
# Augmented cropped images saved !
# Data/Smoking/114.jpg
# Cropped image: (85, 150) (589, 598)
# Augmented cropped images saved !
# Data/Smoking/115.jpg
# Cropped image: (65, 363) (303, 585)
# Augmented cropped images saved !
# Data/Smoking/116.jpg
# Cropped image: (24, 244) (259, 598)
# Augmented cropped images saved !
# Data/Smoking/117.jpg
# Cropped image: (235, 372) (561, 636)
# Augmented cropped images saved !
# Data/Smoking/118.jpg
# Cropped image: (208, 256) (515, 563)
# Augmented cropped images saved !
# Data/Smoking/119.jpg
# Cropped image: (1, 15) (119, 325)
# Augmented cropped images saved !
# Data/Smoking/12.jpg
# Cropped image: (101, 134) (398, 597)
# Augmented cropped images saved !
# Data/Smoking/120.jpg
# Cropped image: (137, 29) (487, 598)
# Augmented cropped images saved !
# Data/Smoking/121.jpg
# Cropped image: (137, 154) (449, 602)
# Augmented cropped images saved !
# Data/Smoking/122.jpg
# Cropped image: (2, 247) (348, 602)
# Augmented cropped images saved !
# Data/Smoking/123.jpg
# Cropped image: (2, 193) (432, 598)
# Cropped image: (6, 185) (440, 598)
# Augmented cropped images saved !
# Data/Smoking/13.jpg
# Cropped image: (64, 72) (549, 596)
# Augmented cropped images saved !
# Data/Smoking/14.jpg
# Cropped image: (85, 171) (357, 520)
# Augmented cropped images saved !
# Data/Smoking/15.jpg
# Cropped image: (203, 52) (528, 465)
# Augmented cropped images saved !
# Data/Smoking/16.jpg
# Cropped image: (159, 173) (431, 597)
# Augmented cropped images saved !
# Data/Smoking/17.jpg
# Cropped image: (11, 99) (468, 454)
# Augmented cropped images saved !
# Data/Smoking/18.jpg
# Cropped image: (201, 298) (408, 596)
# Augmented cropped images saved !
# Data/Smoking/19.jpg
# Cropped image: (154, 172) (377, 582)
# Augmented cropped images saved !
# Data/Smoking/2.jpg
# Cropped image: (65, 164) (545, 597)
# Augmented cropped images saved !
# Data/Smoking/20.jpg
# Cropped image: (235, 67) (425, 523)
# Augmented cropped images saved !
# Data/Smoking/21.jpg
# Cropped image: (135, 143) (598, 604)
# Augmented cropped images saved !
# Data/Smoking/22.jpg
# Cropped image: (7, 4) (349, 484)
# Augmented cropped images saved !
# Data/Smoking/23.jpg
# Cropped image: (2, 160) (602, 593)
# Augmented cropped images saved !
# Data/Smoking/24.jpg
# Cropped image: (1, 231) (350, 595)
# Augmented cropped images saved !
# Data/Smoking/25.jpg
# Cropped image: (148, 30) (546, 552)
# Augmented cropped images saved !
# Data/Smoking/26.jpg
# Cropped image: (54, 53) (589, 588)
# Augmented cropped images saved !
# Data/Smoking/27.jpg
# Cropped image: (3, 121) (305, 599)
# Augmented cropped images saved !
# Data/Smoking/28.jpg
# Cropped image: (95, 230) (252, 535)
# Augmented cropped images saved !
# Data/Smoking/29.jpg
# Cropped image: (3, 110) (519, 592)
# Augmented cropped images saved !
# Data/Smoking/3.jpg
# Cropped image: (230, 218) (609, 593)
# Augmented cropped images saved !
# Data/Smoking/30.jpg
# Cropped image: (1, 372) (250, 617)
# Augmented cropped images saved !
# Data/Smoking/31.jpg
# Cropped image: (176, 114) (450, 505)
# Augmented cropped images saved !
# Data/Smoking/32.jpg
# Cropped image: (141, 221) (460, 598)
# Augmented cropped images saved !
# Data/Smoking/33.jpg
# Cropped image: (204, 107) (366, 370)
# Augmented cropped images saved !
# Data/Smoking/34.jpg
# Cropped image: (125, 153) (481, 587)
# Augmented cropped images saved !
# Data/Smoking/35.jpg
# Cropped image: (98, 36) (438, 488)
# Augmented cropped images saved !
# Data/Smoking/36.jpg
# Cropped image: (12, 191) (502, 598)
# Augmented cropped images saved !
# Data/Smoking/37.jpg
# Cropped image: (154, 200) (566, 574)
# Augmented cropped images saved !
# Data/Smoking/38.jpg
# Cropped image: (180, 56) (473, 468)
# Augmented cropped images saved !
# Data/Smoking/39.jpg
# Cropped image: (113, 13) (359, 350)
# Augmented cropped images saved !
# Data/Smoking/4.jpg
# Cropped image: (335, 217) (594, 510)
# Augmented cropped images saved !
# Data/Smoking/40.jpg
# Cropped image: (140, 314) (470, 615)
# Augmented cropped images saved !
# Data/Smoking/41.jpg
# Cropped image: (175, 155) (487, 417)
# Augmented cropped images saved !
# Data/Smoking/42.jpg
# Cropped image: (103, 9) (610, 608)
# Augmented cropped images saved !
# Data/Smoking/43.jpg
# Cropped image: (269, 148) (631, 607)
# Augmented cropped images saved !
# Data/Smoking/44.jpg
# Cropped image: (20, 155) (465, 626)
# Augmented cropped images saved !
# Data/Smoking/45.jpg
# Cropped image: (317, 203) (607, 598)
# Augmented cropped images saved !
# Data/Smoking/46.jpg
# Cropped image: (2, 282) (267, 581)
# Augmented cropped images saved !
# Data/Smoking/47.jpg
# Cropped image: (107, 58) (382, 556)
# Augmented cropped images saved !
# Data/Smoking/48.jpg
# Cropped image: (1, 186) (406, 592)
# Augmented cropped images saved !
# Data/Smoking/49.jpg
# Data/Smoking/5.jpg
# Cropped image: (194, 39) (570, 461)
# Augmented cropped images saved !
# Data/Smoking/50.jpg
# Cropped image: (139, 11) (605, 596)
# Augmented cropped images saved !
# Data/Smoking/51.jpg
# Cropped image: (201, 137) (280, 292)
# Augmented cropped images saved !
# Data/Smoking/52.jpg
# Cropped image: (11, 67) (333, 592)
# Cropped image: (5, 148) (308, 596)
# Cropped image: (6, 151) (323, 618)
# Augmented cropped images saved !
# Data/Smoking/53.jpg
# Cropped image: (99, 182) (409, 603)
# Augmented cropped images saved !
# Data/Smoking/54.jpg
# Cropped image: (57, 289) (306, 580)
# Augmented cropped images saved !
# Data/Smoking/55.jpg
# Cropped image: (148, 195) (439, 507)
# Augmented cropped images saved !
# Data/Smoking/56.jpg
# Cropped image: (163, 146) (449, 604)
# Augmented cropped images saved !
# Data/Smoking/57.jpg
# Cropped image: (167, 331) (417, 626)
# Augmented cropped images saved !
# Data/Smoking/58.jpg
# Cropped image: (156, 266) (327, 521)
# Augmented cropped images saved !
# Data/Smoking/59.jpg
# Cropped image: (186, 68) (523, 388)
# Augmented cropped images saved !
# Data/Smoking/6.jpg
# Cropped image: (222, 114) (489, 403)
# Augmented cropped images saved !
# Data/Smoking/60.jpg
# Cropped image: (8, 138) (514, 596)
# Augmented cropped images saved !
# Data/Smoking/61.jpg
# Cropped image: (72, 113) (427, 525)
# Augmented cropped images saved !
# Data/Smoking/62.jpg
# Cropped image: (8, 284) (284, 614)
# Augmented cropped images saved !
# Data/Smoking/63.jpg
# Cropped image: (56, 15) (541, 602)
# Augmented cropped images saved !
# Data/Smoking/64.jpg
# Cropped image: (5, 219) (290, 606)
# Augmented cropped images saved !
# Data/Smoking/65.jpg
# Cropped image: (157, 44) (507, 620)
# Augmented cropped images saved !
# Data/Smoking/66.jpg
# Cropped image: (144, 22) (433, 583)
# Augmented cropped images saved !
# Data/Smoking/67.jpg
# Cropped image: (149, 288) (459, 637)
# Augmented cropped images saved !
# Data/Smoking/68.jpg
# Cropped image: (181, 109) (559, 645)
# Augmented cropped images saved !
# Data/Smoking/69.jpg
# Cropped image: (7, 4) (475, 642)
# Augmented cropped images saved !
# Data/Smoking/7.jpg
# Cropped image: (148, 93) (458, 588)
# Data/Smoking/70.jpg
# Cropped image: (27, 20) (567, 604)
# Cropped image: (40, 25) (448, 304)
# Augmented cropped images saved !
# Data/Smoking/71.jpg
# Cropped image: (65, 118) (386, 499)
# Augmented cropped images saved !
# Data/Smoking/72.jpg
# Cropped image: (137, 7) (597, 598)
# Augmented cropped images saved !
# Data/Smoking/73.jpg
# Cropped image: (210, 86) (465, 454)
# Augmented cropped images saved !
# Data/Smoking/74.jpg
# Cropped image: (213, 37) (546, 333)
# Augmented cropped images saved !
# Data/Smoking/75.jpg
# Cropped image: (8, 20) (374, 443)
# Augmented cropped images saved !
# Data/Smoking/76.jpg
# Cropped image: (311, 56) (501, 520)
# Augmented cropped images saved !
# Data/Smoking/77.jpg
# Cropped image: (248, 190) (503, 600)
# Augmented cropped images saved !
# Data/Smoking/78.jpg
# Cropped image: (13, 240) (270, 592)
# Augmented cropped images saved !
# Data/Smoking/79.jpg
# Cropped image: (77, 230) (305, 508)
# Augmented cropped images saved !
# Data/Smoking/8.jpg
# Cropped image: (128, 8) (648, 599)
# Augmented cropped images saved !
# Data/Smoking/80.jpg
# Cropped image: (215, 93) (577, 632)
# Augmented cropped images saved !
# Data/Smoking/81.jpg
# Cropped image: (160, 145) (495, 624)
# Augmented cropped images saved !
# Data/Smoking/82.jpg
# Cropped image: (300, 86) (551, 419)
# Augmented cropped images saved !
# Data/Smoking/83.jpg
# Cropped image: (151, 344) (482, 610)
# Cropped image: (155, 276) (517, 613)
# Augmented cropped images saved !
# Data/Smoking/84.jpg
# Cropped image: (253, 165) (518, 590)
# Augmented cropped images saved !
# Data/Smoking/85.jpg
# Cropped image: (40, 68) (458, 604)
# Augmented cropped images saved !
# Data/Smoking/86.jpg
# Cropped image: (60, 331) (454, 630)
# Augmented cropped images saved !
# Data/Smoking/87.jpg
# Cropped image: (1, 6) (308, 618)
# Augmented cropped images saved !
# Data/Smoking/88.jpg
# Cropped image: (170, 34) (452, 512)
# Augmented cropped images saved !
# Data/Smoking/89.jpg
# Cropped image: (115, 152) (451, 450)
# Augmented cropped images saved !
# Data/Smoking/9.jpg
# Cropped image: (120, 15) (891, 703)
# Augmented cropped images saved !
# Data/Smoking/90.jpg
# Cropped image: (13, 11) (635, 627)
# Augmented cropped images saved !
# Data/Smoking/91.jpg
# Cropped image: (196, 107) (546, 558)
# Augmented cropped images saved !
# Data/Smoking/92.jpg
# Cropped image: (259, 120) (523, 478)
# Augmented cropped images saved !
# Data/Smoking/93.jpg
# Cropped image: (223, 103) (543, 626)
# Augmented cropped images saved !
# Data/Smoking/94.jpg
# Cropped image: (94, 203) (431, 605)
# Augmented cropped images saved !
# Data/Smoking/95.jpg
# Cropped image: (3, 211) (389, 601)
# Augmented cropped images saved !
# Data/Smoking/96.jpg
# Cropped image: (168, 8) (586, 591)
# Augmented cropped images saved !
# Data/Smoking/97.jpg
# Cropped image: (99, 5) (475, 514)
# Augmented cropped images saved !
# Data/Smoking/98.jpg
# Cropped image: (45, 197) (329, 499)
# Augmented cropped images saved !
# Data/Smoking/99.jpg
# Cropped image: (86, 121) (494, 568)
# Augmented cropped images saved !
