# %%
import os

# %%
# %cd D:\Python Projects\Cigarette Detection\smoking___Google_Search
# Out:
# D:\Python Projects\Cigarette Detection\smoking___Google_Search

# %%
# %cd smoking___Google_Search
# Out:
# [WinError 2] The system cannot find the file specified: 'smoking___Google_Search'
# C:\Users\SPACE

# %%
# %cd ..
# Out:
# D:\Python Projects

# %%
# !cd
# Out:
# D:\Python Projects\Cigarette Detection\smoking___Google_Search

# %%
# ren "00sa.jpg" "00sb.jpg"
count = 0
for file in os.listdir():
    frmt = '.jpg'
    name = str(count)+frmt
    print(file)
    print(name)
    # !ren "{file}" "{name}"
    count += 1
    print('_______')
#     if count == 5:
#         break
# Out:
# 0.jpg
# 0.jpg
# _______
# 1.jpg
# 1.jpg
# _______
# 2.jpg
# 2.jpg
# _______
# 3.jpg
# 3.jpg
# _______
# 4.jpg
# 4.jpg
# _______
# 5.jpg
# 5.jpg
# _______
# 6.jpg
# 6.jpg
# _______
# 7.jpg
# 7.jpg
# _______
# images (100).jpg
# 8.jpg
# _______
# images (13).jpg
# 9.jpg
# _______
# images (14).jpg
# 10.jpg
# _______
# images (15).jpg
# 11.jpg
# _______
# images (17).jpg
# 12.jpg
# _______
# images (21).jpg
# 13.jpg
# _______
# images (24).jpg
# 14.jpg
# _______
# images (28).jpg
# 15.jpg
# _______
# images (3).jpg
# 16.jpg
# _______
# images (32).jpg
# 17.jpg
# _______
# images (35).jpg
# 18.jpg
# _______
# images (41).jpg
# 19.jpg
# _______
# images (43).jpg
# 20.jpg
# _______
# images (44).jpg
# 21.jpg
# _______
# images (46).jpg
# 22.jpg
# _______
# images (47).jpg
# 23.jpg
# _______
# images (48).jpg
# 24.jpg
# _______
# images (52).jpg
# 25.jpg
# _______
# images (55).jpg
# 26.jpg
# _______
# images (59).jpg
# 27.jpg
# _______
# images (6).jpg
# 28.jpg
# _______
# images (63).jpg
# ...
